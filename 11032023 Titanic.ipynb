# %% [markdown]
# ### TITANIC

# %%
import pandas as pd

# %%
df = pd.read_csv('./titanic.csv')

# %% [markdown]
# #### HEAD

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  ... Embarked WikiId  \
# 0      0         A/5 21171   7.2500  ...        S  691.0
# 1      0          PC 17599  71.2833  ...        C   90.0
# 2      0  STON/O2. 3101282   7.9250  ...        S  865.0
# 3      0            113803  53.1000  ...        S  127.0
# ...

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
# 5            6       0.0       3
# 6            7       0.0       1
# 7            8       0.0       3
# 8            9       1.0       3
# 9           10       1.0       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.tail(10)
# Out:
#       PassengerId  Survived  Pclass  \
# 1299         1300       NaN       3
# 1300         1301       NaN       3
# 1301         1302       NaN       3
# 1302         1303       NaN       1
# 1303         1304       NaN       3
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                  Name     Sex   Age  SibSp  \
# 1299                  Riordan, Miss. Johanna Hannah""  female   NaN      0
# 1300                        Peacock, Miss. Treasteall  female   3.0      1
# 1301                           Naughton, Miss. Hannah  female   NaN      0
# 1302  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 1303                   Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 1304                               Spector, Mr. Woolf    male   NaN      0
# ...

# %%
df.sample()
# Out:
#      PassengerId  Survived  Pclass                       Name   Sex   Age  \
# 127          128       1.0       3  Madsen, Mr. Fridtjof Arne  male  24.0
#
#      SibSp  Parch   Ticket    Fare  ... Embarked WikiId  \
# 127      0      0  C 17369  7.1417  ...        S  993.0
#
#                      Name_wiki Age_wiki           Hometown      Boarded  \
# 127  Madsen, Mr. Fridtjof Arne     24.0  Trondheim, Norway  Southampton
#
#                 Destination Lifeboat Body Class
# 127  Brooklyn, New York, US       13  NaN   3.0
#
# [1 rows x 21 columns]

# %%
df.describe().T
# Out:
#               count        mean         std   min       25%       50%  \
# PassengerId  1309.0  655.000000  378.020061  1.00  328.0000  655.0000
# Survived      891.0    0.383838    0.486592  0.00    0.0000    0.0000
# Pclass       1309.0    2.294882    0.837836  1.00    2.0000    3.0000
# Age          1046.0   29.881138   14.413493  0.17   21.0000   28.0000
# SibSp        1309.0    0.498854    1.041658  0.00    0.0000    0.0000
# Parch        1309.0    0.385027    0.865560  0.00    0.0000    0.0000
# Fare         1308.0   33.295479   51.758668  0.00    7.8958   14.4542
# WikiId       1304.0  658.534509  380.377373  1.00  326.7500  661.5000
# Age_wiki     1302.0   29.415829   13.758954  0.17   21.0000   28.0000
# Class        1304.0    2.291411    0.840852  1.00    1.7500    3.0000
#
#                  75%        max
# PassengerId  982.000  1309.0000
# Survived       1.000     1.0000
# Pclass         3.000     3.0000
# Age           39.000    80.0000
# ...

# %%
df.shape
# Out:
# (1309, 21)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'WikiId', 'Name_wiki',
#        'Age_wiki', 'Hometown', 'Boarded', 'Destination', 'Lifeboat', 'Body',
#        'Class'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
#  12  WikiId       1304 non-null   float64
#  13  Name_wiki    1304 non-null   object
#  14  Age_wiki     1302 non-null   float64
#  15  Hometown     1304 non-null   object
#  16  Boarded      1304 non-null   object
#  17  Destination  1304 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# WikiId            5
# Name_wiki         5
# Age_wiki          7
# Hometown          5
# Boarded           5
# Destination       5
# Lifeboat        807
# Body           1179
# Class             5
# dtype: int64

# %% [markdown]
# ### Null Percentage

# %%
df.isnull().mean()*100
# Out:
# PassengerId     0.000000
# Survived       31.932773
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            20.091673
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.076394
# Cabin          77.463713
# Embarked        0.152788
# WikiId          0.381971
# Name_wiki       0.381971
# Age_wiki        0.534759
# Hometown        0.381971
# Boarded         0.381971
# Destination     0.381971
# Lifeboat       61.650115
# Body           90.068755
# Class           0.381971
# dtype: float64

# %% [markdown]
# ### Dropping the columns

# %%
df.drop(columns=['Body','Lifeboat','Cabin','PassengerId'])
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304       NaN       3                                 Spector, Mr. Woolf
# 1305       NaN       1                       Oliva y Ocana, Dona. Fermina
# 1306       NaN       3                       Saether, Mr. Simon Sivertsen
# 1307       NaN       3                                Ware, Mr. Frederick
# 1308       NaN       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Embarked  \
# ...

# %%
df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.drop(columns=['Body','Lifeboat','Cabin','PassengerId'],inplace=True)

# %%
df
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304       NaN       3                                 Spector, Mr. Woolf
# 1305       NaN       1                       Oliva y Ocana, Dona. Fermina
# 1306       NaN       3                       Saether, Mr. Simon Sivertsen
# 1307       NaN       3                                Ware, Mr. Frederick
# 1308       NaN       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Embarked  \
# ...

# %%
df.Pclass.unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df.Sex.value_counts()
# Out:
# male      843
# female    466
# Name: Sex, dtype: int64

# %%
df.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %% [markdown]
# ### Filling Nan Values

# %%
df.Embarked.value_counts()
# Out:
# S    914
# C    270
# Q    123
# Name: Embarked, dtype: int64

# %%
df.Embarked.fillna("S", inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Embarked         0
# WikiId           5
# Name_wiki        5
# Age_wiki         7
# Hometown         5
# Boarded          5
# Destination      5
# Class            5
# dtype: int64

# %%
fare_mean = df.Fare.mean()
fare_mean
# Out:
# 33.2954792813456

# %%
df.Fare.fillna(fare_mean, inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age            263
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# WikiId           5
# Name_wiki        5
# Age_wiki         7
# Hometown         5
# Boarded          5
# Destination      5
# Class            5
# dtype: int64

# %%
df.Age.value_counts()
# Out:
# 24.0    47
# 22.0    43
# 21.0    41
# 30.0    40
# 18.0    39
#         ..
# 23.5     1
# 70.5     1
# 55.5     1
# 20.5     1
# 38.5     1
# Name: Age, Length: 98, dtype: int64

# %%
df.Age.fillna(24.0, inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# WikiId           5
# Name_wiki        5
# Age_wiki         7
# Hometown         5
# Boarded          5
# Destination      5
# Class            5
# dtype: int64

# %%
df.drop(columns=['Name_wiki','WikiId'], inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# Age_wiki         7
# Hometown         5
# Boarded          5
# Destination      5
# Class            5
# dtype: int64

# %%
df.Age_wiki.value_counts()
# Out:
# 22.00    62
# 24.00    56
# 21.00    51
# 28.00    47
# 18.00    46
#          ..
# 74.00     1
# 67.00     1
# 0.33      1
# 0.58      1
# 0.17      1
# Name: Age_wiki, Length: 78, dtype: int64

# %%
df.Age_wiki.fillna(22.00, inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# Age_wiki         0
# Hometown         5
# Boarded          5
# Destination      5
# Class            5
# dtype: int64

# %%
df
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304       NaN       3                                 Spector, Mr. Woolf
# 1305       NaN       1                       Oliva y Ocana, Dona. Fermina
# 1306       NaN       3                       Saether, Mr. Simon Sivertsen
# 1307       NaN       3                                Ware, Mr. Frederick
# 1308       NaN       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Embarked  \
# ...

# %%
df.Boarded.unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', 'Belfast', nan],
#       dtype=object)

# %%
df.Boarded.value_counts()
# Out:
# Southampton    916
# Cherbourg      259
# Queenstown     119
# Belfast         10
# Name: Boarded, dtype: int64

# %%
df.Boarded.fillna('Southampton', inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# Age_wiki         0
# Hometown         5
# Boarded          0
# Destination      5
# Class            5
# dtype: int64

# %%
ht=df.Hometown.mode()

# %%
ht
# Out:
# 0    New York, New York, US
# Name: Hometown, dtype: object

# %%
df.Hometown.fillna(' New York, New York, US', inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# Age_wiki         0
# Hometown         0
# Boarded          0
# Destination      5
# Class            5
# dtype: int64

# %%
dst=df.Destination.mode()

# %%
dst
# Out:
# 0    New York City
# Name: Destination, dtype: object

# %%
df.Destination.fillna('New York City',inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# Age_wiki         0
# Hometown         0
# Boarded          0
# Destination      0
# Class            5
# dtype: int64

# %%
df.Class.unique()
# Out:
# array([ 3.,  1.,  2., nan])

# %%
df.Class.value_counts()
# Out:
# 3.0    706
# 1.0    326
# 2.0    272
# Name: Class, dtype: int64

# %%
df.Class.fillna(3.0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived       418
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# Age_wiki         0
# Hometown         0
# Boarded          0
# Destination      0
# Class            0
# dtype: int64

# %%
df.Survived.value_counts()
# Out:
# 0.0    549
# 1.0    342
# Name: Survived, dtype: int64

# %%
df.Survived.fillna(0.0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# Age_wiki       0
# Hometown       0
# Boarded        0
# Destination    0
# Class          0
# dtype: int64

# %% [markdown]
# ### Groupby And Query

# %%
df
# Out:
#       Survived  Pclass                                               Name  \
# 0          0.0       3                            Braund, Mr. Owen Harris
# 1          1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2          1.0       3                             Heikkinen, Miss. Laina
# 3          1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304       0.0       3                                 Spector, Mr. Woolf
# 1305       0.0       1                       Oliva y Ocana, Dona. Fermina
# 1306       0.0       3                       Saether, Mr. Simon Sivertsen
# 1307       0.0       3                                Ware, Mr. Frederick
# 1308       0.0       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Embarked  \
# ...

# %%
Sex_Survived = df.groupby(["Sex"])["Survived"].sum()
Sex_Survived
# Out:
# Sex
# female    233.0
# male      109.0
# Name: Survived, dtype: float64

# %%
Pclass_Survived = df.groupby(["Pclass"])["Survived"].sum()
Pclass_Survived
# Out:
# Pclass
# 1    136.0
# 2     87.0
# 3    119.0
# Name: Survived, dtype: float64

# %% [markdown]
# ### Boarded from Southampton

# %%
Boarded_Southampton=df.query("Boarded == 'Southampton'")

# %%
Boarded_Southampton
# Out:
#       Survived  Pclass                                             Name  \
# 0          0.0       3                          Braund, Mr. Owen Harris
# 2          1.0       3                           Heikkinen, Miss. Laina
# 3          1.0       1     Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4          0.0       3                         Allen, Mr. William Henry
# 6          0.0       1                          McCarthy, Mr. Timothy J
# ...        ...     ...                                              ...
# 1302       0.0       1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 1303       0.0       3                   Henriksson, Miss. Jenny Lovisa
# 1304       0.0       3                               Spector, Mr. Woolf
# 1306       0.0       3                     Saether, Mr. Simon Sivertsen
# 1307       0.0       3                              Ware, Mr. Frederick
#
#          Sex   Age  SibSp  Parch              Ticket     Fare Embarked  \
# ...

# %%
Pclass_Fare = df.groupby(["Pclass"])["Fare"].sum()
Pclass_Fare
# Out:
# Pclass
# 1    28265.404300
# 2     5866.637400
# 3     9451.740679
# Name: Fare, dtype: float64

# %%
Pclass_3class = df.query("Pclass == 3")
Pclass_3class
# Out:
#       Survived  Pclass                            Name     Sex   Age  SibSp  \
# 0          0.0       3         Braund, Mr. Owen Harris    male  22.0      1
# 2          1.0       3          Heikkinen, Miss. Laina  female  26.0      0
# 4          0.0       3        Allen, Mr. William Henry    male  35.0      0
# 5          0.0       3                Moran, Mr. James    male  24.0      0
# 7          0.0       3  Palsson, Master. Gosta Leonard    male   2.0      3
# ...        ...     ...                             ...     ...   ...    ...
# 1303       0.0       3  Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 1304       0.0       3              Spector, Mr. Woolf    male  24.0      0
# 1306       0.0       3    Saether, Mr. Simon Sivertsen    male  38.5      0
# 1307       0.0       3             Ware, Mr. Frederick    male  24.0      0
# 1308       0.0       3        Peter, Master. Michael J    male  24.0      1
#
# ...

# %%
Pclass_Age30 = df.query("Age == 30")

# %%
Pclass_Age30
# Out:
#       Survived  Pclass                                               Name  \
# 79         1.0       3                           Dowdell, Miss. Elizabeth
# 157        0.0       3                                    Corn, Mr. Harry
# 178        0.0       2                                 Hale, Mr. Reginald
# 213        0.0       2                        Givard, Mr. Hans Kristensen
# 219        0.0       2                                 Harris, Mr. Walter
# 244        0.0       3                               Attalah, Mr. Sleiman
# 253        0.0       3                           Lobb, Mr. William Arthur
# 257        1.0       1                               Cherry, Miss. Gladys
# 286        1.0       3                            de Mulder, Mr. Theodore
# 308        0.0       2                                Abelson, Mr. Samuel
# 309        1.0       1                     Francatelli, Miss. Laura Mabel
# 322        1.0       2                          Slayter, Miss. Hilda Mary
# ...

# %%
Pclass_Age30.Survived.value_counts()
# Out:
# 0.0    30
# 1.0    10
# Name: Survived, dtype: int64

# %%
survived_age = df.groupby(["Age"])["Survived"].sum() 
survived_age
# Out:
# Age
# 0.17     0.0
# 0.33     0.0
# 0.42     1.0
# 0.67     1.0
# 0.75     2.0
#         ...
# 70.50    0.0
# 71.00    0.0
# 74.00    0.0
# 76.00    0.0
# 80.00    1.0
# Name: Survived, Length: 98, dtype: float64

# %%
survived_age = df.query("Survived == 1.0")
survived_age
# Out:
#      Survived  Pclass                                               Name  \
# 1         1.0       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1.0       3                             Heikkinen, Miss. Laina
# 3         1.0       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 8         1.0       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9         1.0       2                Nasser, Mrs. Nicholas (Adele Achem)
# ..        ...     ...                                                ...
# 875       1.0       3                   Najib, Miss. Adele Kiamie "Jane"
# 879       1.0       1      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 880       1.0       2       Shelley, Mrs. William (Imanita Parrish Hall)
# 887       1.0       1                       Graham, Miss. Margaret Edith
# 889       1.0       1                              Behr, Mr. Karl Howell
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Embarked  Age_wiki  \
# ...
