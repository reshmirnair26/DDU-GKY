# %% [markdown]
# ## TITANIC DIAGRAMS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('titanic.csv')
data.sample(10)
# Out:
#       PassengerId  Survived  Pclass                          Name     Sex  \
# 290           291       1.0       1  Barber, Miss. Ellen "Nellie"  female
# 121           122       0.0       3    Moore, Mr. Leonard Charles    male
# 425           426       0.0       3        Wiseman, Mr. Phillippe    male
# 739           740       0.0       3            Nankoff, Mr. Minko    male
# 601           602       0.0       3          Slabenoff, Mr. Petco    male
# 1031         1032       NaN       3   Goodwin, Miss. Jessie Allis  female
# 484           485       1.0       1       Bishop, Mr. Dickinson H    male
# 371           372       0.0       3     Wiklund, Mr. Jakob Alfred    male
# 504           505       1.0       1         Maioni, Miss. Roberta  female
# 99            100       0.0       2             Kantor, Mr. Sinai    male
#
#        Age  SibSp  Parch      Ticket     Fare  ... Embarked  WikiId  \
# 290   26.0      0      0       19877  78.8500  ...        S    68.0
# ...

# %%
data.describe()
# Out:
#        PassengerId    Survived       Pclass          Age        SibSp  \
# count  1309.000000  891.000000  1309.000000  1046.000000  1309.000000
# mean    655.000000    0.383838     2.294882    29.881138     0.498854
# std     378.020061    0.486592     0.837836    14.413493     1.041658
# min       1.000000    0.000000     1.000000     0.170000     0.000000
# 25%     328.000000    0.000000     2.000000    21.000000     0.000000
# 50%     655.000000    0.000000     3.000000    28.000000     0.000000
# 75%     982.000000    1.000000     3.000000    39.000000     1.000000
# max    1309.000000    1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare       WikiId     Age_wiki        Class
# count  1309.000000  1308.000000  1304.000000  1302.000000  1304.000000
# mean      0.385027    33.295479   658.534509    29.415829     2.291411
# std       0.865560    51.758668   380.377373    13.758954     0.840852
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
#  12  WikiId       1304 non-null   float64
#  13  Name_wiki    1304 non-null   object
#  14  Age_wiki     1302 non-null   float64
#  15  Hometown     1304 non-null   object
#  16  Boarded      1304 non-null   object
#  17  Destination  1304 non-null   object
# ...

# %%
data.shape
# Out:
# (1309, 21)

# %%
data.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# WikiId            5
# Name_wiki         5
# Age_wiki          7
# Hometown          5
# Boarded           5
# Destination       5
# Lifeboat        807
# Body           1179
# Class             5
# dtype: int64

# %%
data.sample(10)
# Out:
#       PassengerId  Survived  Pclass                        Name     Sex  \
# 609           610       1.0       1   Shutes, Miss. Elizabeth W  female
# 783           784       0.0       3      Johnston, Mr. Andrew G    male
# 1150         1151       NaN       3    Midtsjo, Mr. Karl Albert    male
# 767           768       0.0       3          Mangan, Miss. Mary  female
# 996           997       NaN       3   Holthen, Mr. Johan Martin    male
# 252           253       0.0       1   Stead, Mr. William Thomas    male
# 1009         1010       NaN       1        Beattie, Mr. Thomson    male
# 644           645       1.0       3      Baclini, Miss. Eugenie  female
# 1189         1190       NaN       1  Loring, Mr. Joseph Holland    male
# 784           785       0.0       3            Ali, Mr. William    male
#
#         Age  SibSp  Parch              Ticket      Fare  ... Embarked  WikiId  \
# 609   40.00      0      0            PC 17582  153.4625  ...        S   138.0
# ...

# %% [markdown]
# ## UNIVARIATE ANALYSIS

# %% [markdown]
# ### 1.KDE PLOT
#
# #### Passenger ID

# %%
plt.figure(figsize=(5,4))
sns.kdeplot(data=data.PassengerId)
plt.show()

# %% [markdown]
# #### Age

# %%
plt.figure(figsize=(5,4))
sns.kdeplot(data=data.Age)
plt.show()

# %% [markdown]
# ### 2.HISTPLOT

# %% [markdown]
# #### Fare

# %%
sns.histplot(data.Fare)
plt.show()

# %% [markdown]
# #### Age

# %%
sns.histplot(data.Age)
plt.show()

# %% [markdown]
# ### 3.BOX PLOT

# %% [markdown]
# #### Fare

# %%
sns.boxplot('Fare', data=data)
plt.show()

# %% [markdown]
# #### Age

# %%
sns.boxplot('Age', data=data)
plt.show()

# %% [markdown]
# ## MULTI VARIATE ANALYSIS
#
# ### 1. LINE PLOT

# %% [markdown]
# #### Age vs Fare

# %%
sns.lineplot('Age', 'Fare', data=data)
plt.title("Age vs Fare")
plt.show()

# %% [markdown]
# #### Age vs Survived

# %%
sns.lineplot('Age', 'Pclass', data=data)
plt.title("Age vs Pclass")
plt.show()

# %% [markdown]
# ### 2. PIE CHART

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'WikiId', 'Name_wiki',
#        'Age_wiki', 'Hometown', 'Boarded', 'Destination', 'Lifeboat', 'Body',
#        'Class'],
#       dtype='object')

# %%
Pclass_Survived = data.groupby(['Pclass'])['Survived'].sum()

# %%
Pclass_Survived
# Out:
# Pclass
# 1    136.0
# 2     87.0
# 3    119.0
# Name: Survived, dtype: float64

# %%
sns.set_style('ticks')
Pclass_Survived.plot.pie()
plt.legend()
plt.show()

# %%
Pclass_Sex_Survived = data.groupby(['Pclass','Sex'])['Survived'].sum()

# %%
Pclass_Sex_Survived.reset_index()
# Out:
#    Pclass     Sex  Survived
# 0       1  female      91.0
# 1       1    male      45.0
# 2       2  female      70.0
# 3       2    male      17.0
# 4       3  female      72.0
# 5       3    male      47.0

# %%
Pclass_Sex_Survived.plot.pie(autopct = '%1.2f%%')
plt.legend(bbox_to_anchor=(1.5, 1), loc='upper left', borderaxespad=0)
plt.show()

# %% [markdown]
# ### 3. BAR CHART
#
# #### Count Plot

# %%
plt.figure(figsize=(5,4))
sns.countplot('Sex', hue = 'Survived',data=data)
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.countplot('Survived', data=data)
plt.show()

# %%
plt.figure(figsize=(5,4))
sns.set_style('darkgrid')
sns.countplot('Pclass', hue='Survived', data=data)
plt.title('Pclass: Survived vs Dead')
plt.show()

# %% [markdown]
# ### 4. FACTOR PLOT

# %%
sns.set_style('ticks')
sns.factorplot('Pclass', 'Survived', hue='Sex', data=data)
plt.show()

# %% [markdown]
# ### 5. VIOLIN PLOT

# %%
sns.set_style('dark')
plt.figure(figsize=(5,4))
sns.violinplot("Sex","Age", hue="Survived", data=data)
plt.show()

# %% [markdown]
# ### 6. BAR PLOT

# %%
plt.figure(figsize=(6,3))
sns.barplot('SibSp', 'Survived', data=data)
plt.title("SibSp & Survived")
plt.show()

# %% [markdown]
# ### 7. PAIR PLOT

# %%
sns.pairplot(data=data)
plt.show()

# %% [markdown]
# ### 8. HEAT MAP

# %%
heat_map = data.corr()
sns.heatmap(heat_map)
plt.show()
